# %%
import sys
import sklearn
import tensorflow as tf
from tensorflow import keras
import matplotlib.pyplot as plt
import numpy as np
import os

# %%
(x_train_all, y_train_all), (x_test, y_test) =keras.datasets.cifar10.load_data()

# %%
x_train_all[0].shape
# Out:
# (32, 32, 3)

# %%
numbers=np.random.randint(0,50000,10)

# %%
for number in numbers:
    image=x_train_all[number]
    plt.show(plt.imshow(image))

# %%
model = keras.models.Sequential()
model.add(keras.layers.Flatten(input_shape=[32, 32,3]))
for layer in range(20):
    model.add(keras.layers.Dense(100, activation="elu",
                                 kernel_initializer="he_normal"))
model.add(keras.layers.Dense(10, activation="softmax"))

# %%
x_valid, x_train = x_train_all[:5000], x_train_all[5000:]
y_valid, y_train = y_train_all[:5000], y_train_all[5000:]

# %%
#Using Adam optimization and early stopping, train the network on the CIFAR10 dataset. You can load it with keras.datasets.cifar10.load_​data(). The dataset is composed of 60,000 32 × 32–pixel color images (50,000 for training, 10,000 for testing) with 10 classes, so you’ll need a softmax output layer with 10 neurons. Remember to search for the right learning rate each time you change the model’s architecture or hyperparameters.
early_stopping_cb = keras.callbacks.EarlyStopping(patience=5,
                                                  restore_best_weights=True)
model.compile(loss="sparse_categorical_crossentropy",
              optimizer=keras.optimizers.Adam(lr=1e-3),
              metrics=["accuracy"])


best_model = model.fit(x_train, y_train, epochs=50,validation_data=(x_valid, y_valid),
                    callbacks=[early_stopping_cb])
# Out:
# Train on 45000 samples, validate on 5000 samples
# Epoch 1/20
# 45000/45000 [==============================] - 11s 243us/sample - loss: 2.0483 - accuracy: 0.2712 - val_loss: 1.9722 - val_accuracy: 0.2560
# Epoch 2/20
# 45000/45000 [==============================] - 9s 210us/sample - loss: 1.9474 - accuracy: 0.2564 - val_loss: 1.9275 - val_accuracy: 0.2718
# Epoch 3/20
# 45000/45000 [==============================] - 10s 211us/sample - loss: 1.8893 - accuracy: 0.2871 - val_loss: 1.8623 - val_accuracy: 0.3066
# Epoch 4/20
# 45000/45000 [==============================] - 11s 236us/sample - loss: 1.8466 - accuracy: 0.3092 - val_loss: 1.8115 - val_accuracy: 0.3156
# Epoch 5/20
# 45000/45000 [==============================] - 10s 215us/sample - loss: 1.8240 - accuracy: 0.3229 - val_loss: 1.8265 - val_accuracy: 0.3204
# Epoch 6/20
# 45000/45000 [==============================] - 9s 208us/sample - loss: 1.7920 - accuracy: 0.3432 - val_loss: 1.7689 - val_accuracy: 0.3440
# Epoch 7/20
# 45000/45000 [==============================] - 9s 204us/sample - loss: 2.1957 - accuracy: 0.3212 - val_loss: 1.8430 - val_accuracy: 0.3146
# Epoch 8/20
# 45000/45000 [==============================] - 9s 205us/sample - loss: 1.8218 - accuracy: 0.3177 - val_loss: 1.9433 - val_accuracy: 0.2814
# Epoch 9/20
# 45000/45000 [==============================] - 9s 211us/sample - loss: 1.7998 - accuracy: 0.3317 - val_loss: 1.7910 - val_accuracy: 0.3118
# Epoch 10/20
# 45000/45000 [==============================] - 9s 210us/sample - loss: 1.7876 - accuracy: 0.3358 - val_loss: 1.7576 - val_accuracy: 0.3500
# Epoch 11/20
# 45000/45000 [==============================] - 10s 214us/sample - loss: 1.7811 - accuracy: 0.3405 - val_loss: 1.8265 - val_accuracy: 0.3334
# Epoch 12/20
# 45000/45000 [==============================] - 11s 237us/sample - loss: 1.7573 - accuracy: 0.3547 - val_loss: 1.7947 - val_accuracy: 0.3424
# Epoch 13/20
# 45000/45000 [==============================] - 10s 232us/sample - loss: 1.7454 - accuracy: 0.3603 - val_loss: 1.7510 - val_accuracy: 0.3628
# Epoch 14/20
# 45000/45000 [==============================] - 11s 234us/sample - loss: 1.7230 - accuracy: 0.3676 - val_loss: 1.7346 - val_accuracy: 0.3614
# Epoch 15/20
# 45000/45000 [==============================] - 10s 220us/sample - loss: 1.7451 - accuracy: 0.3597 - val_loss: 1.7661 - val_accuracy: 0.3280
# Epoch 16/20
# 45000/45000 [==============================] - 10s 221us/sample - loss: 1.7423 - accuracy: 0.3562 - val_loss: 1.7628 - val_accuracy: 0.3588
# Epoch 17/20
# 45000/45000 [==============================] - 11s 239us/sample - loss: 1.7263 - accuracy: 0.3638 - val_loss: 1.7238 - val_accuracy: 0.3778
# Epoch 18/20
# 45000/45000 [==============================] - 11s 236us/sample - loss: 1.7285 - accuracy: 0.3698 - val_loss: 1.7289 - val_accuracy: 0.3676
# Epoch 19/20
# 45000/45000 [==============================] - 11s 241us/sample - loss: 1.8864 - accuracy: 0.3374 - val_loss: 1.7380 - val_accuracy: 0.3614
# Epoch 20/20
# 45000/45000 [==============================] - 10s 232us/sample - loss: 1.7476 - accuracy: 0.3556 - val_loss: 1.7463 - val_accuracy: 0.3494

# %%
#add batch normalization
model = keras.models.Sequential()
model.add(keras.layers.Flatten(input_shape=[32, 32,3]))
model.add(keras.layers.BatchNormalization())

for layer in range(20):
    model.add(keras.layers.Dense(100, activation="elu",
                                 kernel_initializer="he_normal"))
    model.add(keras.layers.BatchNormalization())
model.add(keras.layers.Dense(10, activation="softmax"))

# %%
model.compile(loss="sparse_categorical_crossentropy",
              optimizer=keras.optimizers.Adam(lr=1e-3),
              metrics=["accuracy"])


best_model = model.fit(x_train, y_train, epochs=50,validation_data=(x_valid, y_valid),
                    callbacks=[early_stopping_cb])
# Out:
# Train on 45000 samples, validate on 5000 samples
# Epoch 1/50
# 45000/45000 [==============================] - 34s 760us/sample - loss: 1.9206 - accuracy: 0.3117 - val_loss: 1.7504 - val_accuracy: 0.3828
# Epoch 2/50
# 45000/45000 [==============================] - 27s 606us/sample - loss: 1.7290 - accuracy: 0.3840 - val_loss: 1.6842 - val_accuracy: 0.3886
# Epoch 3/50
# 45000/45000 [==============================] - 29s 634us/sample - loss: 1.6638 - accuracy: 0.4091 - val_loss: 1.5861 - val_accuracy: 0.4202
# Epoch 4/50
# 45000/45000 [==============================] - 27s 601us/sample - loss: 1.6100 - accuracy: 0.4311 - val_loss: 1.5756 - val_accuracy: 0.4434
# Epoch 5/50
# 45000/45000 [==============================] - 28s 623us/sample - loss: 1.5686 - accuracy: 0.4441 - val_loss: 1.4948 - val_accuracy: 0.4616
# Epoch 6/50
# 45000/45000 [==============================] - 28s 616us/sample - loss: 1.5312 - accuracy: 0.4640 - val_loss: 1.4780 - val_accuracy: 0.4856
# Epoch 7/50
# 45000/45000 [==============================] - 26s 588us/sample - loss: 1.4879 - accuracy: 0.4733 - val_loss: 1.4670 - val_accuracy: 0.4766
# Epoch 8/50
# 45000/45000 [==============================] - 27s 592us/sample - loss: 1.4610 - accuracy: 0.4840 - val_loss: 1.4423 - val_accuracy: 0.4780
# Epoch 9/50
# 45000/45000 [==============================] - 26s 587us/sample - loss: 1.4338 - accuracy: 0.4946 - val_loss: 1.4412 - val_accuracy: 0.4856
# Epoch 10/50
# 45000/45000 [==============================] - 26s 586us/sample - loss: 1.4060 - accuracy: 0.5069 - val_loss: 1.4090 - val_accuracy: 0.5046
# Epoch 11/50
# 45000/45000 [==============================] - 26s 583us/sample - loss: 1.3832 - accuracy: 0.5112 - val_loss: 1.3853 - val_accuracy: 0.5180
# Epoch 12/50
# 45000/45000 [==============================] - 27s 595us/sample - loss: 1.3581 - accuracy: 0.5239 - val_loss: 1.3957 - val_accuracy: 0.5152
# Epoch 13/50
# 45000/45000 [==============================] - 26s 589us/sample - loss: 1.3321 - accuracy: 0.5323 - val_loss: 1.4183 - val_accuracy: 0.5042
# Epoch 14/50
# 45000/45000 [==============================] - 26s 585us/sample - loss: 1.3158 - accuracy: 0.5390 - val_loss: 1.4001 - val_accuracy: 0.5118
# Epoch 15/50
# 45000/45000 [==============================] - 27s 593us/sample - loss: 1.2955 - accuracy: 0.5440 - val_loss: 1.3699 - val_accuracy: 0.5138
# Epoch 16/50
# 45000/45000 [==============================] - 27s 589us/sample - loss: 1.2818 - accuracy: 0.5528 - val_loss: 1.3902 - val_accuracy: 0.5178
# Epoch 17/50
# 45000/45000 [==============================] - 27s 592us/sample - loss: 1.2576 - accuracy: 0.5622 - val_loss: 1.3636 - val_accuracy: 0.5246
# Epoch 18/50
# 45000/45000 [==============================] - 27s 595us/sample - loss: 1.2432 - accuracy: 0.5646 - val_loss: 1.3454 - val_accuracy: 0.5270
# Epoch 19/50
# 45000/45000 [==============================] - 29s 643us/sample - loss: 1.2273 - accuracy: 0.5721 - val_loss: 1.3592 - val_accuracy: 0.5186
# Epoch 20/50
# 45000/45000 [==============================] - 30s 664us/sample - loss: 1.2217 - accuracy: 0.5720 - val_loss: 1.3204 - val_accuracy: 0.5420
# Epoch 21/50
# 45000/45000 [==============================] - 31s 699us/sample - loss: 1.1980 - accuracy: 0.5818 - val_loss: 1.3637 - val_accuracy: 0.5270
# Epoch 22/50
# 45000/45000 [==============================] - 29s 639us/sample - loss: 1.1891 - accuracy: 0.5842 - val_loss: 1.3353 - val_accuracy: 0.5398
# Epoch 23/50
# 45000/45000 [==============================] - 29s 641us/sample - loss: 1.1693 - accuracy: 0.5906 - val_loss: 1.3742 - val_accuracy: 0.5230
# Epoch 24/50
# 45000/45000 [==============================] - 28s 633us/sample - loss: 1.1597 - accuracy: 0.5959 - val_loss: 1.3559 - val_accuracy: 0.5312
# Epoch 25/50
# 45000/45000 [==============================] - 30s 675us/sample - loss: 1.1460 - accuracy: 0.5998 - val_loss: 1.3568 - val_accuracy: 0.5258

# %%
#the model is converging faster with batch normalization


model = keras.models.Sequential()
model.add(keras.layers.Flatten(input_shape=[32, 32,3]))

for layer in range(20):
    model.add(keras.layers.Dense(100, activation="selu",
                                 kernel_initializer="lecun_normal"))
model.add(keras.layers.Dense(10, activation="softmax"))

# %%
pixel_means = x_train.mean(axis=0, keepdims=True)
pixel_stds = x_train.std(axis=0, keepdims=True)
x_train_scaled = (x_train - pixel_means) / pixel_stds
x_valid_scaled = (x_valid - pixel_means) / pixel_stds

# %%
model.compile(loss="sparse_categorical_crossentropy",
              optimizer=keras.optimizers.Adam(lr=1e-3),
              metrics=["accuracy"])


best_model = model.fit(x_train_scaled, y_train, epochs=50,validation_data=(x_valid_scaled, y_valid),
                    callbacks=[early_stopping_cb])
# Out:
# Train on 45000 samples, validate on 5000 samples
# Epoch 1/50
# 45000/45000 [==============================] - 45s 1ms/sample - loss: 1.9688 - accuracy: 0.2374 - val_loss: 1.8766 - val_accuracy: 0.2846
# Epoch 2/50
# 45000/45000 [==============================] - 15s 341us/sample - loss: 3.3378 - accuracy: 0.2927 - val_loss: 1.8750 - val_accuracy: 0.2918
# Epoch 3/50
# 45000/45000 [==============================] - 16s 361us/sample - loss: 1.8187 - accuracy: 0.3116 - val_loss: 1.8318 - val_accuracy: 0.3174
# Epoch 4/50
# 45000/45000 [==============================] - 16s 348us/sample - loss: 1.7702 - accuracy: 0.3302 - val_loss: 1.7467 - val_accuracy: 0.3468
# Epoch 5/50
# 45000/45000 [==============================] - 16s 348us/sample - loss: 1.7264 - accuracy: 0.3504 - val_loss: 1.7357 - val_accuracy: 0.3550
# Epoch 6/50
# 45000/45000 [==============================] - 16s 350us/sample - loss: 1.8106 - accuracy: 0.3235 - val_loss: 1.7369 - val_accuracy: 0.3484
# Epoch 7/50
# 45000/45000 [==============================] - 16s 352us/sample - loss: 1.6823 - accuracy: 0.3709 - val_loss: 1.6784 - val_accuracy: 0.3798
# Epoch 8/50
# 45000/45000 [==============================] - 16s 350us/sample - loss: 1.6460 - accuracy: 0.3864 - val_loss: 1.6605 - val_accuracy: 0.3790
# Epoch 9/50
# 45000/45000 [==============================] - 16s 351us/sample - loss: 1.6133 - accuracy: 0.4018 - val_loss: 1.6617 - val_accuracy: 0.4020
# Epoch 10/50
# 45000/45000 [==============================] - 16s 352us/sample - loss: 1.5885 - accuracy: 0.4175 - val_loss: 1.6565 - val_accuracy: 0.3944
# Epoch 11/50
# 45000/45000 [==============================] - 16s 356us/sample - loss: 1.5597 - accuracy: 0.4297 - val_loss: 1.5874 - val_accuracy: 0.4274
# Epoch 12/50
# 45000/45000 [==============================] - 17s 372us/sample - loss: 1.5277 - accuracy: 0.4438 - val_loss: 1.5655 - val_accuracy: 0.4364
# Epoch 13/50
# 45000/45000 [==============================] - 16s 347us/sample - loss: 1.4945 - accuracy: 0.4566 - val_loss: 1.5893 - val_accuracy: 0.4232
# Epoch 14/50
# 45000/45000 [==============================] - 15s 341us/sample - loss: 1.4681 - accuracy: 0.4673 - val_loss: 1.5787 - val_accuracy: 0.4230
# Epoch 15/50
# 45000/45000 [==============================] - 16s 364us/sample - loss: 1.4369 - accuracy: 0.4811 - val_loss: 1.5561 - val_accuracy: 0.4406
# Epoch 16/50
# 45000/45000 [==============================] - 16s 360us/sample - loss: 1.4065 - accuracy: 0.4905 - val_loss: 1.5902 - val_accuracy: 0.4526
# Epoch 17/50
# 45000/45000 [==============================] - 17s 367us/sample - loss: 1.3798 - accuracy: 0.5014 - val_loss: 1.5867 - val_accuracy: 0.4486
# Epoch 18/50
# 45000/45000 [==============================] - 16s 362us/sample - loss: 1.3523 - accuracy: 0.5147 - val_loss: 1.6004 - val_accuracy: 0.4542
# Epoch 19/50
# 45000/45000 [==============================] - 17s 370us/sample - loss: 1.3346 - accuracy: 0.5237 - val_loss: 1.5150 - val_accuracy: 0.4800
# Epoch 20/50
# 45000/45000 [==============================] - 18s 390us/sample - loss: 1.3168 - accuracy: 0.5318 - val_loss: 1.5138 - val_accuracy: 0.4716
# Epoch 21/50
# 45000/45000 [==============================] - 17s 377us/sample - loss: 1.2960 - accuracy: 0.5398 - val_loss: 1.4978 - val_accuracy: 0.4752
# Epoch 22/50
# 45000/45000 [==============================] - 16s 360us/sample - loss: 1.5482 - accuracy: 0.4860 - val_loss: 1.7134 - val_accuracy: 0.3928
# Epoch 23/50
# 45000/45000 [==============================] - 16s 365us/sample - loss: 1.4823 - accuracy: 0.4640 - val_loss: 1.5819 - val_accuracy: 0.4432
# Epoch 24/50
# 45000/45000 [==============================] - 16s 364us/sample - loss: 1.3919 - accuracy: 0.5000 - val_loss: 1.5626 - val_accuracy: 0.4472
# Epoch 25/50
# 45000/45000 [==============================] - 16s 364us/sample - loss: 1.3380 - accuracy: 0.5216 - val_loss: 1.5886 - val_accuracy: 0.4498
# Epoch 26/50
# 45000/45000 [==============================] - 17s 383us/sample - loss: 1.3057 - accuracy: 0.5342 - val_loss: 1.5415 - val_accuracy: 0.4498
